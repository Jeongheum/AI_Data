# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeongheum/AI_Data/blob/main/datamanimType1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# %%
dataUrl ='https://raw.githubusercontent.com/Datamanim/pandas/main/winter.csv'

# %%
df = pd.read_csv(dataUrl)

# %%
df.head()
# Out:
#    Year      City     Sport Discipline               Athlete Country Gender  \
# 0  1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA    Men
# 1  1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA    Men
# 2  1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA    Men
# 3  1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA    Men
# 4  1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI    Men
#
#              Event   Medal
# 0  Military Patrol  Bronze
# 1  Military Patrol  Bronze
# 2  Military Patrol  Bronze
# 3  Military Patrol  Bronze
# 4  Military Patrol    Gold

# %%
Ans = df.loc[df.Country == 'KOR']

# %%
Ans
# Out:
#       Year         City    Sport                 Discipline          Athlete  \
# 2652  1992  Albertville  Skating  Short Track Speed Skating      LEE, Jun-Ho
# 2653  1992  Albertville  Skating  Short Track Speed Skating     KIM, Ki-Hoon
# 2671  1992  Albertville  Skating  Short Track Speed Skating     KIM, Ki-Hoon
# 2672  1992  Albertville  Skating  Short Track Speed Skating      LEE, Jun-Ho
# 2673  1992  Albertville  Skating  Short Track Speed Skating       MO, Ji-Soo
# ...    ...          ...      ...                        ...              ...
# 5528  2014        Sochi  Skating  Short Track Speed Skating   PARK, Seung-Hi
# 5544  2014        Sochi  Skating              Speed skating   JOO, Hyong Jun
# 5545  2014        Sochi  Skating              Speed skating   KIM, Cheol Min
# 5546  2014        Sochi  Skating              Speed skating  LEE, Seung Hoon
# 5565  2014        Sochi  Skating              Speed skating    LEE, Sang Hwa
#
#      Country Gender         Event   Medal
# ...

# %%
Ans.pivot_table(index='Year', columns = 'Medal', aggfunc='size').fillna(0)
# Out:
# Medal  Bronze  Gold  Silver
# Year
# 1992      1.0   5.0     1.0
# 1994      1.0   8.0     1.0
# 1998      2.0   6.0     4.0
# 2002      0.0   5.0     2.0
# 2006      2.0  14.0     3.0
# 2010      2.0   6.0    10.0
# 2014      2.0   7.0     5.0

# %%
df.pivot_table(index='Sport', columns = 'Gender', aggfunc='size').fillna(0)
# Out:
# Gender       Men  Women
# Sport
# Biathlon     270    150
# Bobsleigh    416     36
# Curling       97     75
# Ice Hockey  1231    305
# Luge         135     45
# Skating      665    564
# Skiing      1130    651

# %%
df.pivot_table(index='Discipline', columns = 'Medal', aggfunc='size').fillna(0)
# Out:
# Medal                      Bronze  Gold  Silver
# Discipline
# Alpine Skiing                 141   143     144
# Biathlon                      139   140     141
# Bobsleigh                     147   134     141
# Cross Country Skiing          263   264     262
# Curling                        56    58      58
# Figure skating                118   122     119
# Freestyle Skiing               34    34      34
# Ice Hockey                    512   510     514
# Luge                           60    62      58
# Nordic Combined                55    55      55
# Short Track Speed Skating      96    97      97
# Skeleton                       10    10      10
# Ski Jumping                    68    69      70
# Snowboard                      30    30      30
# Speed skating                 190   193     197

# %%
#### 07 Merge, Concat

# %%
Dataurl = 'https://raw.githubusercontent.com/Datamanim/pandas/main/mergeTEst.csv'

# %%
df = pd.read_csv(Dataurl, index_col=0)

# %%
df.head(3)
# Out:
#                2010    2011    2012    2013   2014    2015    2016    2017  \
# Location
# Afghanistan  64.023  61.640  59.367  57.170  55.08  53.107  51.267  49.560
# Albania      11.803  10.807   9.943   9.267   8.79   8.493   8.363   8.363
# Algeria      23.540  22.907  22.450  22.117  21.85  21.587  21.257  20.850
#
#                2018    2019
# Location
# Afghanistan  47.983  46.453
# Albania       8.453   8.597
# Algeria      20.407  19.930

# %%
df.head()
# Out:
#       Location    2010    2011    2012    2013   2014    2015    2016    2017  \
# 0  Afghanistan  64.023  61.640  59.367  57.170  55.08  53.107  51.267  49.560
# 1      Albania  11.803  10.807   9.943   9.267   8.79   8.493   8.363   8.363
# 2      Algeria  23.540  22.907  22.450  22.117  21.85  21.587  21.257  20.850
# 3      Andorra   4.240   4.033   3.843   3.667   3.49   3.330   3.187   3.060
# 4       Angola  75.713  71.280  67.233  63.570  60.43  57.757  55.510  53.460
#
#      2018    2019
# 0  47.983  46.453
# 1   8.453   8.597
# 2  20.407  19.930
# 3   2.933   2.827
# 4  51.757  50.093

# %%
df1 = df.iloc[:4, :]

# %%
df2 = df.iloc[4:,:]

# %%
display(df1)
# Out:
#                2010    2011    2012    2013   2014    2015    2016    2017  \
# Location
# Afghanistan  64.023  61.640  59.367  57.170  55.08  53.107  51.267  49.560
# Albania      11.803  10.807   9.943   9.267   8.79   8.493   8.363   8.363
# Algeria      23.540  22.907  22.450  22.117  21.85  21.587  21.257  20.850
# Andorra       4.240   4.033   3.843   3.667   3.49   3.330   3.187   3.060
#
#                2018    2019
# Location
# Afghanistan  47.983  46.453
# Albania       8.453   8.597
# Algeria      20.407  19.930
# Andorra       2.933   2.827

# %%
display(df2)
# Out:
#                        2010    2011    2012    2013    2014    2015    2016  \
# Location
# Angola               75.713  71.280  67.233  63.570  60.430  57.757  55.510
# Antigua and Barbuda   8.667   8.223   7.807   7.420   7.070   6.757   6.483
# Argentina            12.887  12.380  11.840  11.283  10.733  10.203   9.683
# Armenia              16.497  15.677  14.897  14.170  13.477  12.817  12.183
# Australia             3.993   3.803   3.623   3.467   3.343   3.253   3.183
# Austria               3.573   3.463   3.333   3.210   3.113   3.043   2.987
#
#                        2017    2018    2019
# Location
# Angola               53.460  51.757  50.093
# Antigua and Barbuda   6.230   6.000   5.783
# Argentina             9.177   8.680   8.227
# Armenia              11.583  11.007  10.497
# Australia             3.137   3.090   3.047
# Austria               2.943   2.897   2.843

# %%
df.head(6)
# Out:
#                        2010    2011    2012    2013   2014    2015    2016  \
# Location
# Afghanistan          64.023  61.640  59.367  57.170  55.08  53.107  51.267
# Albania              11.803  10.807   9.943   9.267   8.79   8.493   8.363
# Algeria              23.540  22.907  22.450  22.117  21.85  21.587  21.257
# Andorra               4.240   4.033   3.843   3.667   3.49   3.330   3.187
# Angola               75.713  71.280  67.233  63.570  60.43  57.757  55.510
# Antigua and Barbuda   8.667   8.223   7.807   7.420   7.07   6.757   6.483
#
#                        2017    2018    2019
# Location
# Afghanistan          49.560  47.983  46.453
# Albania               8.363   8.453   8.597
# Algeria              20.850  20.407  19.930
# Andorra               3.060   2.933   2.827
# Angola               53.460  51.757  50.093
# Antigua and Barbuda   6.230   6.000   5.783

# %%
total = pd.concat([df1, df2])

# %%
total.head()
# Out:
#                2010    2011    2012    2013   2014    2015    2016    2017  \
# Location
# Afghanistan  64.023  61.640  59.367  57.170  55.08  53.107  51.267  49.560
# Albania      11.803  10.807   9.943   9.267   8.79   8.493   8.363   8.363
# Algeria      23.540  22.907  22.450  22.117  21.85  21.587  21.257  20.850
# Andorra       4.240   4.033   3.843   3.667   3.49   3.330   3.187   3.060
# Angola       75.713  71.280  67.233  63.570  60.43  57.757  55.510  53.460
#
#                2018    2019
# Location
# Afghanistan  47.983  46.453
# Albania       8.453   8.597
# Algeria      20.407  19.930
# Andorra       2.933   2.827
# Angola       51.757  50.093

# %%
df3 = df.iloc[:2, :4]
df4 = df.iloc[5:, 3:]

# %%
display(df3)
display(df4)
# Out:
#                2010    2011    2012    2013
# Location
# Afghanistan  64.023  61.640  59.367  57.170
# Albania      11.803  10.807   9.943   9.267
#                        2013    2014    2015    2016    2017    2018    2019
# Location
# Antigua and Barbuda   7.420   7.070   6.757   6.483   6.230   6.000   5.783
# Argentina            11.283  10.733  10.203   9.683   9.177   8.680   8.227
# Armenia              14.170  13.477  12.817  12.183  11.583  11.007  10.497
# Australia             3.467   3.343   3.253   3.183   3.137   3.090   3.047
# Austria               3.210   3.113   3.043   2.987   2.943   2.897   2.843

# %%
total2 = pd.merge (df3, df4, inner)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-43786ee3d13c> in <cell line: 1>()
# ----> 1 total2 = pd.merge (df3, df4, inner)
#
# NameError: name 'inner' is not defined

# %%
total2 = pd.concat ([df3, df4], join='inner')

# %%
total2.head()
# Out:
#                        2013
# Location
# Afghanistan          57.170
# Albania               9.267
# Antigua and Barbuda   7.420
# Argentina            11.283
# Armenia              14.170

# %%
total2 = pd.concat ([df3, df4], join='inner').fillna(0)

# %%
total3=pd.concat([df3, df4], join='outer').fillna(0)

# %%
total3.head()
# Out:
#                        2010    2011    2012    2013    2014    2015    2016  \
# Location
# Afghanistan          64.023  61.640  59.367  57.170   0.000   0.000   0.000
# Albania              11.803  10.807   9.943   9.267   0.000   0.000   0.000
# Antigua and Barbuda   0.000   0.000   0.000   7.420   7.070   6.757   6.483
# Argentina             0.000   0.000   0.000  11.283  10.733  10.203   9.683
# Armenia               0.000   0.000   0.000  14.170  13.477  12.817  12.183
#
#                        2017    2018    2019
# Location
# Afghanistan           0.000   0.000   0.000
# Albania               0.000   0.000   0.000
# Antigua and Barbuda   6.230   6.000   5.783
# Argentina             9.177   8.680   8.227
# Armenia              11.583  11.007  10.497

# %%
df5 = df.T.iloc[:7, :3]

# %%
df6 = df.T.iloc[6:, 2:5]

# %%
display(df5)
display(df6)
# Out:
# Location  Afghanistan  Albania  Algeria
# 2010           64.023   11.803   23.540
# 2011           61.640   10.807   22.907
# 2012           59.367    9.943   22.450
# 2013           57.170    9.267   22.117
# 2014           55.080    8.790   21.850
# 2015           53.107    8.493   21.587
# 2016           51.267    8.363   21.257
# Location  Algeria  Andorra  Angola
# 2016       21.257    3.187  55.510
# 2017       20.850    3.060  53.460
# 2018       20.407    2.933  51.757
# 2019       19.930    2.827  50.093

# %%
ans = pd.merge(df5, df6, on='Algeria', how ='inner')

# %%
ans.head()
# Out:
# Location  Afghanistan  Albania  Algeria  Andorra  Angola
# 0              51.267    8.363   21.257    3.187   55.51

# %%
ans2 = pd.merge(df5, df6, on='Algeria', how ='outer')
ans2.head()
# Out:
# Location  Afghanistan  Albania  Algeria  Andorra  Angola
# 0              64.023   11.803   23.540      NaN     NaN
# 1              61.640   10.807   22.907      NaN     NaN
# 2              59.367    9.943   22.450      NaN     NaN
# 3              57.170    9.267   22.117      NaN     NaN
# 4              55.080    8.790   21.850      NaN     NaN

# %%
dataurl = 'https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv'

# %%
df = pd.read_csv(dataurl, index_col=0)

# %%
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %%
df.channelId.value_counts().head(10).index
# Out:
# Index(['UCszFjh7CEfwDb7UUGb4RzCQ', 'UClzB2iZ5jPoTNz0S-QU6Wiw',
#        'UCtm_QoN2SIxwCE-59shX7Qg', 'UCaKod3X1Tn4c7Ci0iUKcvzQ',
#        'UCiwQRG2sCcfjKkgxMEdJGPg', 'UChbE5OZQ6dRHECsX0tEPEZQ',
#        'UCLkAepWjdylmXSltofFvsYQ', 'UCQ2O-iftmnlfrBuNsUUTofQ',
#        'UCtfriFvIe5gIe8wRWb8UTMg', 'UCRuSxVu4iqTK5kCh90ntAgA'],
#       dtype='object')

# %%
df.loc[df.dislikes > df.likes]
# Out:
#                      title   channelTitle  categoryId  view_count  likes  \
# 1805      안녕하세요, 핫도그TV입니다.          핫도그TV          24     1610542  16339
# 2008      안녕하세요, 핫도그TV입니다.          핫도그TV          24     1926778  16728
# 2233      안녕하세요, 핫도그TV입니다.          핫도그TV          24     2093168  16905
# 2452      안녕하세요, 핫도그TV입니다.          핫도그TV          24     2180815  17005
# 2680      안녕하세요, 핫도그TV입니다.          핫도그TV          24     2232343  17104
# ...                    ...            ...         ...         ...    ...
# 52344    ALL IN | EP04. 추락  Gen.G esports          20      113017    774
# 52551  ALL IN | EP05. 불협화음  Gen.G esports          20      135083    889
# 52554    ALL IN | EP04. 추락  Gen.G esports          20      115047    781
# 52772  ALL IN | EP05. 불협화음  Gen.G esports          20      138531    902
# 52776    ALL IN | EP04. 추락  Gen.G esports          20      117669    788
#
#        dislikes  comment_count                 channelId trending_date2
# ...

# %%
df.loc[df.dislikes > df.likes].channelTitle.unique()
# Out:
# array(['핫도그TV', 'ASMR 애정TV', '하얀트리HayanTree', '양팡 YangPang',
#        '철구형 (CHULTUBE)', '왜냐맨하우스', '(MUTUBE)와꾸대장봉준', '오메킴TV', '육지담',
#        'MapleStory_KR', 'ROAD FIGHTING CHAMPIONSHIP', '사나이 김기훈',
#        '나혼자산다 STUDIO', 'Gen.G esports'], dtype=object)

# %%
ans =df[['channelTitle','channelId']].drop_duplicates().channelId.value_counts()

# %%
ans[ans>1]
# Out:
# UCtQYhzJWFai1y30UIA3uwYQ    3
# UC98TOxKQk4aLcx0EjIK0LkQ    3
# UC4nEQI74rZkFKlUSwi0ur4A    2
# UCn64fSqF2l4rkkjtQUpku2A    2
# UCjO3ji06DxmTM1RrzLVwmkA    2
#                            ..
# UCk5bhZYNtbPJyNLRxN8D8NQ    2
# UCSiGNrrL2lAc0-_MfcUUUHA    2
# UCiBKp3KgsQCYT9Z2XxdBpbQ    2
# UCUEX0L7GHPs95m8S7G6kWVA    2
# UC-IYpdOqjkER7B6cnChwlhA    2
# Name: channelId, Length: 71, dtype: int64

# %%
df['trending_date2']=pd.to_datetime(df.trending_date2)

# %%
df.trending_date2.head()
# Out:
# 0   2021-01-01
# 1   2021-01-01
# 2   2021-01-01
# 3   2021-01-01
# 4   2021-01-01
# Name: trending_date2, dtype: datetime64[ns]

# %%
df.loc[df.trending_date2.dt.day_name() == 'Sunday'].categoryId.value_counts().index[0]
# Out:
# 24
